# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x=np.arange(0,math.pi*2,0.05)

# %%
x
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25])

# %%
y=np.sin(x)
plt.plot(x,y)
plt.xlabel('angle')
plt.ylabel('sin value')
plt.title('sin')
plt.show()

# %%
x=np.linspace(-3,3,30)
y=x*x
plt.plot(x,y,'gP-.')#green marker=P linestyle=-.
plt.show()

# %%
x=np.linspace(-3,3,30)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x),'r*')
plt.plot(x,-np.sin(x),'g+')
plt.show()

# %%
x=np.arange(0,math.pi*2,0.05)
y=np.sin(x)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('angle')
ax.set_title('sine')
ax.set_ylabel('sin value')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x1=[23,24,34,54,66,77]
x2=[55,66,77,88,99,100]
y=[10,13,14,18,22,28]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
line1=ax.plot(x1,y,'g*')
line2=ax.plot(x2,y,'bP')
ax.legend(labels=('x1','x2'),loc='lower right')
ax.set_title('x1 x2 vs y')
ax.set_xlabel('x1 x2')
ax.set_ylabel('y')
plt.show()

# %%
plt.subplot(221)
plt.plot(range(10))
plt.subplot(212,facecolor='r')
plt.plot(range(20))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(121)
plt.plot(range(10))
plt.subplot(122,facecolor='r')
plt.plot(range(20))
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting in the first row and first column
plt.subplot(121)
plt.plot(range(10))

# Plotting in the first row and second column with a red background color
plt.subplot(122, facecolor='r')
plt.plot(range(20))

plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and adjust the size
plt.figure(figsize=(8, 6))  # Adjust the size as needed

# Plotting in the first row and first column
plt.subplot(221)
plt.plot(range(10))

# Plotting in the first row and second column with a red background color
plt.subplot(222, facecolor='r')  # Adjusted the index to place it in the first row and second column
plt.plot(range(20))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(211, facecolor='r')  
plt.plot(range(20))
plt.subplot(212, facecolor='r')  
plt.plot(range(20))
plt.show()

# %%
import numpy as np
plt.subplot(1,2,1)
plt.plot(np.arange(0,12))
plt.subplot(1,2,2)
plt.plot(np.arange(0,22))
plt.show()

# %%
plt.subplot(221)
plt.plot(np.arange(0,9))

plt.subplot(222)
plt.plot(np.arange(0,7))

plt.subplot(223)
plt.plot(np.arange(0,7))
plt.subplot(224)
plt.plot(np.arange(0,7))
plt.show()

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([10,21,30])
ax2=fig.add_subplot(326,facecolor='k')
ax2.plot([12,18,22,])

# %%
import numpy as np
import math

x=np.arange(0,math.pi*2,.05)
fig=plt.figure()
ax1=fig.add_axes([0,0,.5,.5])
ax2=fig.add_axes([0.5,0.5,0.5,0.5])
y=np.sin(x)
ax1.plot(x,y,'m')
ax2.plot(x,np.cos(x),'c')
ax1.set_title('SIN ANGLE')
ax2.set_title('COS ANGLE')
plt.show()

# %%
fig,a=plt.subplots(2,3)
x=np.arange(20)
a[0][0].plot(x,x*x)
a[0][0].set_title('SQUARE')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('SQRT')
a[0][2].plot(x,x**3)
a[0][2].set_title('CUBE')
a[1][0].plot(x,np.cbrt(x))
a[1][0].set_title('CBRT')
a[1][1].plot(x,np.sqrt(x))
a[1][1].set_title('SQRTs')
a[1][2].plot(x,x*2)
a[1][2].set_title('MULTIPLE')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(1, 2, figsize=(15, 7))

# Using axs to access subplots
sns.histplot(data=df, x='average', bins=30, kde=True, color='g', ax=axs[0])
sns.histplot(data=df, x='average', kde=True, hue='gender', ax=axs[1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       4 fig, axs = plt.subplots(1, 2, figsize=(15, 7))
#       6 # Using axs to access subplots
# ----> 7 sns.histplot(data=df, x='average', bins=30, kde=True, color='g', ax=axs[0])
#       8 sns.histplot(data=df, x='average', kde=True, hue='gender', ax=axs[1])
#      10 plt.show()
#
# NameError: name 'df' is not defined

# %%
fig,ax=plt.subplots(2,3)

ax[0][0].plot(np.arange(0,10))
ax[0][0].set_title('a')

ax[0][1].plot(np.arange(0,22))
ax[0][1].set_title('b')

ax[0][2].plot(np.arange(0,15))
ax[0][2].set_title('c')

ax[1][0].plot(np.arange(0,13))
ax[1][0].set_title('d')

ax[1][1].plot(np.arange(0,11))
ax[1][1].set_title('e')

ax[1][2].plot(np.arange(0,14))
ax[1][2].set_title('f')
fig.tight_layout()
plt.show()

# %%
a1=plt.subplot2grid((3,3),(0,0))
a1.plot(np.arange(0,20))
a2=plt.subplot2grid((3,3),(0,1),rowspan=2,colspan=2)
a2.plot(np.arange(0,12))
a3=plt.subplot2grid((3,3),(1,0),rowspan=2,colspan=1)
a3.plot(np.arange(0,11))
a4=plt.subplot2grid((3,3),(2,1),rowspan=1,colspan=2)
a4.plot(np.arange(0,22))
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
data=np.random.normal(10,50,20)
data1=np.random.normal(1,30,20)
data2=np.random.normal(10,100,200)

plt.scatter(x=data,y=data1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating the data
data = np.random.normal(10, 50, 20)
data1 = np.random.normal(1, 30, 20)
data2 = np.random.normal(10, 100, 200)

# Creating the scatter plot
plt.scatter(x=data, y=data1)

# Displaying the plot
plt.show()

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.boxplot(data2)
plt.show()

# %%
datas=[data,data1,data2]
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
v=axes.violinplot(datas)
plt.show()

# %%
prdt=[22,24,55,4,6,6,45,11,45]
prdt1=[2,40,25,24,16,60,40,19,15]
plt.scatter(prdt,prdt1,c=prdt1,cmap="summer")
plt.colorbar(label='products',orientation='vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

np.random.seed(1)
x = [2, 4, 6]
y = [3.6, 5, 4.2]
yerr = [0.9, 1.2, 0.5]

# plot:
fig, ax = plt.subplots()

ax.errorbar(x, y, yerr, fmt='o', linewidth=2, capsize=6)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import axes3d

plt.style.use('_mpl-gallery')

# Make data
X, Y, Z = axes3d.get_test_data(0.05)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
# Removing tick labels
ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)

# %%
print(X.shape)
print(Y.shape)
print(X)
print(Y)
# Out:
# (40,)
# (40,)
# [-5.   -4.75 -4.5  -4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25
#  -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75]
# [-5.   -4.75 -4.5  -4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25
#  -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75]

# %%
X, Y = np.meshgrid(X, Y)

# %%
print(X.shape)
print(Y.shape)
print(X)
# Out:
# (40, 40)
# (40, 40)
# [[-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  ...
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]]

# %%
print(Y)
# Out:
# [[-5.   -5.   -5.   ... -5.   -5.   -5.  ]
#  [-4.75 -4.75 -4.75 ... -4.75 -4.75 -4.75]
#  [-4.5  -4.5  -4.5  ... -4.5  -4.5  -4.5 ]
#  ...
#  [ 4.25  4.25  4.25 ...  4.25  4.25  4.25]
#  [ 4.5   4.5   4.5  ...  4.5   4.5   4.5 ]
#  [ 4.75  4.75  4.75 ...  4.75  4.75  4.75]]

# %%
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(1)
x = [2, 4, 6]
D = np.random.gamma(4, size=(3, 50))

# plot:
fig, ax = plt.subplots()

ax.eventplot(D, orientation="vertical", lineoffsets=x, linewidth=0.75)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()
ax.ecdf(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 12
#      10 # plot:
#      11 fig, ax = plt.subplots()
# ---> 12 ax.ecdf(x)
#      13 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'ecdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)
# Compute ECDF
x_sorted = np.sort(x)
y = np.arange(1, len(x) + 1) / len(x)
# plot:
fig, ax = plt.subplots()
ax.step(x_sorted, y, where='post')
ax.set_xlabel('Value')
ax.set_ylabel('ECDF')
ax.set_title('Empirical Cumulative Distribution Function')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
x = np.linspace(-4, 4, 6)
y = np.linspace(-4, 4, 6)
print(x)
print(y)
# Out:
# [-4.  -2.4 -0.8  0.8  2.4  4. ]
# [-4.  -2.4 -0.8  0.8  2.4  4. ]

# %%
X, Y = np.meshgrid(x, y)
U = X + Y
V = Y - X
print(X)
print('---')
print(Y)
# Out:
# [[-4.  -2.4 -0.8  0.8  2.4  4. ]
#  [-4.  -2.4 -0.8  0.8  2.4  4. ]
#  [-4.  -2.4 -0.8  0.8  2.4  4. ]
#  [-4.  -2.4 -0.8  0.8  2.4  4. ]
#  [-4.  -2.4 -0.8  0.8  2.4  4. ]
#  [-4.  -2.4 -0.8  0.8  2.4  4. ]]
# ---
# [[-4.  -4.  -4.  -4.  -4.  -4. ]
#  [-2.4 -2.4 -2.4 -2.4 -2.4 -2.4]
#  [-0.8 -0.8 -0.8 -0.8 -0.8 -0.8]
#  [ 0.8  0.8  0.8  0.8  0.8  0.8]
#  [ 2.4  2.4  2.4  2.4  2.4  2.4]
#  [ 4.   4.   4.   4.   4.   4. ]]

# %%
# plot
fig, ax = plt.subplots()

ax.quiver(X, Y, U, V, color="C0", angles='xy',
          scale_units='xy', scale=5, width=.015)

ax.set(xlim=(-5, 5), ylim=(-5, 5))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-2, 2, 10)
y = np.linspace(-2, 2, 10)
X, Y = np.meshgrid(x, y)
U = -Y
V = X
plt.quiver(X, Y, U, V)
plt.title('Quiver Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=10)

#ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
levels = np.linspace(np.min(Z), np.max(Z), 7)

# plot
fig, ax = plt.subplots()

ax.contour(X, Y, Z, levels=levels)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make a stream function:
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
# make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)

# plot:
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
X, Y = np.meshgrid([1, 2, 3, 4],[1, 2, 3, 4])
angle = np.pi / 180 * np.array([[15., 30, 35, 45],
                                [25., 40, 55, 60],
                                [35., 50, 65, 75],
                                [45., 60, 75, 90]])
amplitude = np.array([[5, 10, 25, 50],
                      [10, 15, 30, 60],
                      [15, 26, 50, 70],
                      [20, 45, 80, 100]])
U = amplitude * np.sin(angle)
V = amplitude * np.cos(angle)

# plot:
fig, ax = plt.subplots()

ax.barbs(X, Y, U, V, barbcolor='C0', flagcolor='C0', length=7, linewidth=1.5)

ax.set(xlim=(0, 4.5), ylim=(0, 4.5))

plt.show()

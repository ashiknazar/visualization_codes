# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
anagrams=sns.load_dataset('anagrams')
anscombe=sns.load_dataset('anscombe')
attention=sns.load_dataset('attention')
brain_networks=sns.load_dataset('brain_networks')
car_crashes=sns.load_dataset('car_crashes')

# %%
anagrams.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
import numpy as np
anagrams['attnr'].nunique()
# Out:
# 2

# %%
data=sns.load_dataset('iris')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = sns.load_dataset('iris')

numeric_data = data.select_dtypes(include=[float, int])

correlation_matrix = numeric_data.corr(numeric_only=True)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# %%
sns.heatmap(correlation_matrix,linewidth=4,linecolor='c',annot=True)
# Out:
# <AxesSubplot: >

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.distplot(data['sepal_length'], kde=True, hist=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6372\1132762518.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_length'], kde=True, hist=True)
# <AxesSubplot: xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(data['sepal_length'], kde=True, hist=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6372\729982244.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_length'], kde=True, hist=True)
# <AxesSubplot: xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(data['sepal_length'], kde=True)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(data['sepal_length'])
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ### bivariate

# %%
print(data.to_string())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
sns.jointplot(data=data,x='sepal_width',y='sepal_length',dropna=True)

# %%
sns.jointplot(data=data,x='sepal_length',y='sepal_width',kind='kde')

# %%
sns.jointplot(data=data,x='sepal_length',y='sepal_width',kind='hist')

# %%
sns.jointplot(data=data,x='sepal_length',y='sepal_width',kind='reg')

# %%
sns.jointplot(data=data,x='sepal_length',height=10,ratio=4,y='sepal_width',kind='reg')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,diag_kind='kde',hue='species')

# %%
sns.stripplot(data)
# Out:
# <AxesSubplot: >

# %%
sns.stripplot(x='species',y='petal_length',jitter=True,data=data,hue='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.stripplot(x='species',y='petal_length',jitter=False,data=data,hue='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.swarmplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>
# C:\Users\user\anaconda3\envs\tf-2\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data)
# Out:
# <AxesSubplot: >

# %%
sns.violinplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',inner='box')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',inner='quartile')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',inner='stick')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',palette='autumn',inner='points',hue='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(data=data,orient='v')
# Out:
# <AxesSubplot: >

# %%
sns.countplot(data,x='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %% [markdown]
# visualize the mean value of a quantitative variable for different levels of a categorical variable, along with confidence intervals around the means.

# %%
sns.pointplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# the y-axis shows the mean variation of the dependent variable (in this case, petal_length) for different values of the independent variable

# %%
#sns.set_theme(style='dark')
sns.set_theme(style='ticks')
sns.pointplot(data=data,x='sepal_width',y='petal_length',hue="species")
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.catplot(data=data,x='species',y='sepal_length',col='species')

# %%
sns.catplot(data=data,x='species',y='sepal_length',col='species',kind='swarm')

# %%
sns.catplot(data=data,x='species',col='species',y='sepal_length',kind='box')

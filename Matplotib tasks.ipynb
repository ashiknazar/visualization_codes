# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Asus\\Downloads\\archive (7)\\insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("Solarize_Light2")
plt.title("Age-Bmi")
plt.plot(data['age'],data['bmi'])
plt.xlabel("x axis",fontsize=18,loc='center')
plt.ylabel("y axis",fontsize=18,loc='center')

plt.show()

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\movie_dataset (1).csv")
data
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
s=data.head(10)
s
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
# 5      5  258000000                  Fantasy Action Adventure
# 6      6  260000000                          Animation Family
# 7      7  280000000          Action Adventure Science Fiction
# 8      8  250000000                  Adventure Fantasy Family
# 9      9  250000000                  Action Adventure Fantasy
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
plt.style.use("Solarize_Light2")
plt.title("Vote_Average - Runtime",color="Green")
plt.xlabel("Vote_Average",fontsize='18',loc="center",color="red")
plt.ylabel("Runtime",fontsize='18',loc="center",color="red")
plt.plot(s['vote_average'],s['runtime'])
plt.show()

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\50_Startups.csv")
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
s=data.head(10)
s
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
plt.style.use("Solarize_Light2")
plt.title("R&D Spend-Administration",color="Green")
plt.xlabel("R&D spend",fontsize='18',loc="center",color="red")
plt.ylabel("Administration",fontsize='18',loc="center",color="red")
plt.plot(data['R&D Spend'],data['Administration'])
plt.show()

# %%
x=s['R&D Spend']
y=s["Administration"]
plt.xlabel("R&D Spend")
plt.ylabel("Administration")
plt.subplot(2,1,1)
plt.plot(x,y)
#plt.xticks(np.arange(120000,160000,100000))
#plt.yticks(np.arange(100000,1400000,20000))
x=s["Administration"]
y=s["Profit"]
plt.xlabel("Administartion")
plt.ylabel("Profit")
plt.subplot(2,1,2)
plt.plot(x,y)
#plt.xticks(np.arange(90000,150000,100000))
#plt.yticks(np.arange(150000,1900000,100000))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#add one,the age and speed of 13 cars:
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

#day two,the age and speed of 15 cars:
x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,color="hotpink")
x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,color='#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","grey","cyan","magenta"])
plt.scatter(x,y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])

plt.scatter(x,y, c=colors,cmap='rainbow')

plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes =np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y, s=sizes)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#if using a jupyter notbook

#%matplotlib inline

x=np.arange(0,6*np.pi,0.1)  #start,stop,step
y=np.sin(x)

plt.plot(x,y)
plt.show()

x=np.arange(0,4*np.pi,0.1)  #start,stop,step
y=np.sin(x)
z=np.cos(x)

plt.plot(x,y,x,z)
plt.show()

# %%
x=np.arange(0,4*np.pi,0.1) #start,stop,step
y=np.sin(x)
z=np.cos(x)
plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 4pi') #string must be enclosed with quotes ''
plt.ylabel('sin(x)and cos(x)')
plt.title('plot of sin and cos from 0 to 4pi')
plt.legend(['sin(x)','cos(x)']) #legend entries as seperate strings in a list
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(0,6*np.pi,0.1)
y=np.sin(x)

plt.subplot(2,1,1)

plt.plot(x,y)

x=np.arange(0,6*np.pi,0.1)
z=np.cos(x)
plt.subplot(2,1,2)

plt.plot(x,z, color="hotpink")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Bar Plot
import matplotlib.pyplot as plt
import numpy as np

grades=["A","B","C","D"]
test1=[3,10,40,35]
#test2=[40,50,30,25]
#test3=[35,55,60,75]

plt.bar(grades,test1)
plt.show()

# %% [markdown]
# # Giving title and label

# %%
grades=["A","B","C","D"]
test1=[3,10,40,35]
#test2=[40,50,30,25]
#test3=[35,55,60,75]

plt.bar(grades,test1)
plt.title('BAR PLOT')
plt.xlabel('Grades')
plt.ylabel('No of students')
plt.show()

# %%
#giving fontcolour,fontsizes
grades=["A","B","C","D"]
test1=[3,10,40,35]
#test2=[40,50,30,25]
#test3=[35,55,60,75]
plt.bar(grades,test1)
plt.title('BAR PLOT',fontsize=15,color='firebrick')

plt.xlabel('Grades',fontsize=15,color='magenta')
plt.ylabel("No: of students",fontsize=15,color='red')
plt.show()

# %% [markdown]
# # giving bar width and alignment

# %%
grades=["A","B","C","D"]
test1=[3,10,40,35]
#test2=[40,50,30,25]
#test3=[35,55,60,75]
plt.bar(grades,test1,color='lime',edgecolor='red',width=0.5,align="center")
plt.title('BAR PLOT',fontsize=15,color='firebrick')

plt.xlabel('Grades',fontsize=15,color='magenta')
plt.ylabel("No: of students",fontsize=15,color='red')
plt.show()

# %% [markdown]
# # linewidth and linestyle

# %%
grades=["A","B","C","D"]
test1=[3,10,40,35]
#test2=[40,50,30,25]
#test3=[35,55,60,75]
plt.bar(grades,test1,color='lime',edgecolor='red',width=0.5,align="center",linestyle="--",linewidth=6)
plt.title('BAR PLOT',fontsize=15,color='firebrick')

plt.xlabel('Grades',fontsize=15,color='magenta')
plt.ylabel("No: of students",fontsize=15,color='red')
plt.show()

# %% [markdown]
# # three bar

# %%
grades=["A","B","C","D"]
test1=[3,10,40,35]
test2=[40,50,30,25]
test3=[35,55,60,75]

index=np.arange(len(grades))

plt.bar(index,test1,width=0.2,align='center',color='red',edgecolor="blue",linewidth=2,label='test1')
plt.bar(index+0.2,test2,width=0.2,align='center',color='lime',edgecolor="k",linewidth=2,label='test2')
plt.bar(index-0.2,test3,width=0.2,align='center',color='cyan',edgecolor="k",linewidth=2,label='test3')
plt.title('BAR PLOT',fontsize=15,color='firebrick')

plt.xlabel('Grades',fontsize=15,color='magenta')
plt.ylabel("No: of students",fontsize=15,color='red')
plt.legend()
plt.show()
print(len(grades))
# Out:
# 4

# %% [markdown]
# # Background set

# %%
grades=["A","B","C","D"]
test1=[3,10,40,35]
test2=[40,50,30,25]
test3=[35,55,60,75]
#for background
plt.figure(figsize=(10,10),facecolor='lightblue',edgecolor='pink',linewidth=5)
plt.style.use("Solarize_Light2")
index=np.arange(len(grades))

plt.bar(index,test1,width=0.2,align='center',color='red',edgecolor='k',linewidth=2,label='test1')
plt.bar(index+0.2,test2,width=0.2,align='center',color='lime',edgecolor='k',linewidth=2,label='test2')
plt.bar(index-0.2,test3,width=0.2,align='center',color='cyan',edgecolor='k',linewidth=2,label='test3')

plt.title('BAR PLOT',fontsize=15,color='firebrick')

plt.xlabel('Grades',fontsize=15,color='magenta')
plt.ylabel("No: of students",fontsize=15,color='red')
plt.legend()
plt.show()

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\User\\Downloads\\insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
s=data.head(10)
s
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.bar(data.age,data.bmi)
plt.title("BAR PLOT",fontsize=15,color="firebrick")
plt.xlabel("age",fontsize=15,color='red')
plt.ylabel("bmi",fontsize=15,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.bar(data.age,data.expenses)
plt.show()

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Asus\\Downloads\\archive (6)\\cancer_dataset.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
plt.bar(data.radius_mean,data.area_mean)
plt.show()

# %% [markdown]
# # pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y=np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
myexplode=[0.5, 0, 0.1, 0]

plt.pie(y,labels=mylabels, explode = myexplode)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
myexplode=[0.2, 0, 0, 0]
plt.pie(y,labels = mylabels, explode=myexplode, shadow= True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
mycolors=["black","hotpink","b", "#4CAF50"]
plt.pie(y,labels= mylabels, colors= mycolors)
plt.show()

# %% [markdown]
# # Draw a basic piechart

# %%
import matplotlib.pyplot as plt
import numpy as np

movies=["comedy","action","romance","drama"]

votes=[2,4,3,7]

plt.pie(votes)
plt.show()

# %% [markdown]
# # Give the title, label also change label distance and legend

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1.2)
plt.legend()
plt.show()

# %% [markdown]
# # explode the values

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,explode=[0.2,0,0.3,0])  #explode used to seperate the wedges
plt.legend(title='Genres')
plt.axis('equal')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # rotating the pie chart

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45)  #explode used to seperate the wedges
plt.legend(title='Genres')
plt.axis('equal')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # see the color of each wedge

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45,radius=30,colors=['lime','red','yellow','violet'])  #explode used to seperate the wedges
plt.legend(title='Genres',loc='lower left')
plt.axis('scaled')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # Display percentage

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45,radius=30,colors=['lime','red','yellow','violet'],
       autopct='%0.3f%%',pctdistance=0.5)  #explode used to seperate the wedges
#autopct attribute is used to specify the distance of the text

#in the slice from the center of the circle

#The ratio b/w the center of each pie slice and the start of the text generated by autopct
plt.legend(title='Genres',loc='upper right')
plt.axis('scaled')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # Set the text properties

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45,radius=30,colors=['lime','red','yellow','violet'],
       autopct='%0.1f%%',pctdistance=0.5,textprops={'fontsize':'15'})  #pass the text properties as dictionary
plt.legend(title='Genres',loc='upper right')
plt.axis('scaled')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # Give the wedge properties

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45,radius=30,colors=['lime','red','yellow','violet'],
       autopct='%0.1f%%',pctdistance=0.5,textprops={'fontsize':'15'},
       wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':'-.'})  #pass the text properties as dictionary
plt.legend(title='Genres',loc=5)
plt.axis('scaled')  #to seperaate the legends from center to equal
plt.show()

# %% [markdown]
# # giving the shadow

# %%
plt.title("Favorite types of movies")
plt.pie(votes,labels=movies,labeldistance=1,startangle=45,radius=30,colors=['lime','red','yellow','violet'],
       autopct='%0.1f%%',pctdistance=0.5,textprops={'fontsize':'15'},
       wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':'-.'},shadow=True)  #pass the text properties as dictionary
plt.legend(title='Genres',loc=5)
plt.axis('scaled')  #to seperaate the legends from center to equal
plt.show()
